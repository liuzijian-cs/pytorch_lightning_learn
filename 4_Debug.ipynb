# %% [markdown]
# # How does Lightning help me debug ?
#
# The Lightning Trainer has a lot of arguments devoted to maximizing your debugging productivity.

# %% [markdown]
# # Set a breakpoint 设置断点
# A breakpoint stops your code execution so you can inspect variables, etc… and allow your code to execute one line at a time.

# %% [markdown]
# # Run all your model code once quickly
# If you’ve ever trained a model for days only to crash during validation or testing then this trainer argument is about to become your best friend.
# > 如果你曾经训练了一个模特好几天，却在验证或测试的时候崩溃了，那么这个训练师的争论将会成为你最好的朋友。
#
# The fast_dev_run argument in the trainer runs 5 batch of training, validation, test and prediction data through your trainer to see if there are any bugs:
# > 教练中的 fast _ dev _ run 参数通过教练运行5批训练、验证、测试和预测数据，以查看是否存在任何错误:

# %%
import lightning as L
trainer = L.Trainer(fast_dev_run=True)
# To change how many batches to use, change the argument to an integer. Here we run 7 batches of each:
trainer = Trainer(fast_dev_run=7)

# %% [markdown]
# # Shorten the epoch length
#
# Sometimes it’s helpful to only use a fraction of your training, val, test, or predict data (or a set number of batches). For example, you can use 20% of the training set and 1% of the validation set.
# On larger datasets like Imagenet, this can help you debug or test a few things faster than waiting for a full epoch.
# > 有时候，只使用一小部分训练、 val、测试或预测数据(或一组固定数量的批处理)是有帮助的。例如，您可以使用训练集的20% 和验证集的1% 。对于较大的数据集，如 Imagenet，这可以帮助您更快地调试或测试一些东西，而不是等待一个完整的纪元。

# %%
# use only 10% of training data and 1% of val data
trainer = Trainer(limit_train_batches=0.1, limit_val_batches=0.01)
# use 10 batches of train and 5 batches of val
trainer = Trainer(limit_train_batches=10, limit_val_batches=5)

# %% [markdown]
# # Run a Sanity Check 完整性检查
#
# Lightning runs 2 steps of validation in the beginning of training. This avoids crashing in the validation loop sometime deep into a lengthy training loop.
# > 闪电运行2步验证在训练的开始。这样可以避免在有时深入到冗长的训练循环中的验证循环中崩溃。

# %%
trainer = Trainer(num_sanity_val_steps=2)

# %% [markdown]
# # Print LightningModule weights summary
#
# Whenever the .fit() function gets called, the Trainer will print the weights summary for the LightningModule.

# %%
trainer.fit(...)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 trainer.fit(...)
#
# NameError: name 'trainer' is not defined

# %% [markdown]
# this generate a table like:
# ```
#   | Name  | Type        | Params
# ----------------------------------
# 0 | net   | Sequential  | 132 K
# 1 | net.0 | Linear      | 131 K
# 2 | net.1 | BatchNorm1d | 1.0 K
# ```
#
# To add the child modules to the summary add a ModelSummary:

# %%
from lightning.pytorch.callbacks import ModelSummary

trainer = Trainer(callbacks=[ModelSummary(max_depth=-1)])

# %% [markdown]
# To print the model summary if .fit() is not called:

# %%
from lightning.pytorch.utilities.model_summary import ModelSummary

model = LitModel()
summary = ModelSummary(model, max_depth=-1)
print(summary)

# %% [markdown]
# To turn off the autosummary use:

# %%
trainer = Trainer(enable_model_summary=False)

# %% [markdown]
# # Print input output layer dimensions
#
# Another debugging tool is to display the intermediate input- and output sizes of all your layers by setting the example_input_array attribute in your LightningModule.
#
# ```python
# class LitModel(LightningModule):
#     def __init__(self, *args, **kwargs):
#         self.example_input_array = torch.Tensor(32, 1, 28, 28)
# ```
#
# With the input array, the summary table will include the input and output layer dimensions:
#
# ```
#   | Name  | Type        | Params | In sizes  | Out sizes
# --------------------------------------------------------------
# 0 | net   | Sequential  | 132 K  | [10, 256] | [10, 512]
# 1 | net.0 | Linear      | 131 K  | [10, 256] | [10, 512]
# 2 | net.1 | BatchNorm1d | 1.0 K  | [10, 512] | [10, 512]
# ```

# %% [markdown]
# # FIND BOTTLENECKS IN YOUR CODE (BASIC)

# %% [markdown]
# ## Find training loop bottlenecks
#
# The most basic profile measures all the key methods across Callbacks, DataModules and the LightningModule in the training loop.
#
# ```python
# trainer = Trainer(profiler="simple")
# ```
#
# Once the .fit() function has completed, you’ll see an output like this:
#
# ```
# FIT Profiler Report
#
# -------------------------------------------------------------------------------------------
# |  Action                                          |  Mean duration (s) |  Total time (s) |
# -------------------------------------------------------------------------------------------
# |  [LightningModule]BoringModel.prepare_data       |  10.0001           |  20.00          |
# |  run_training_epoch                              |  6.1558            |  6.1558         |
# |  run_training_batch                              |  0.0022506         |  0.015754       |
# |  [LightningModule]BoringModel.optimizer_step     |  0.0017477         |  0.012234       |
# |  [LightningModule]BoringModel.val_dataloader     |  0.00024388        |  0.00024388     |
# |  on_train_batch_start                            |  0.00014637        |  0.0010246      |
# |  [LightningModule]BoringModel.teardown           |  2.15e-06          |  2.15e-06       |
# |  [LightningModule]BoringModel.on_train_start     |  1.644e-06         |  1.644e-06      |
# |  [LightningModule]BoringModel.on_train_end       |  1.516e-06         |  1.516e-06      |
# |  [LightningModule]BoringModel.on_fit_end         |  1.426e-06         |  1.426e-06      |
# |  [LightningModule]BoringModel.setup              |  1.403e-06         |  1.403e-06      |
# |  [LightningModule]BoringModel.on_fit_start       |  1.226e-06         |  1.226e-06      |
# -------------------------------------------------------------------------------------------
# ```
#
# 在这个报告中，我们可以看到最慢的函数是 ready _ data。现在你可以明白为什么数据准备会减慢你的训练。
#
# 简单侧写器自动测量训练循环中使用的所有标准方法，包括:
# - on_train_epoch_start
# - on_train_epoch_end
# - on_train_batch_start
# - model_backward
# - on_after_backward
# - optimizer_step
# - on_train_batch_end
# - on_training_end
# - etc…

# %% [markdown]
# ## Profile the time within every function 分析每一个函数的时间
#
# To profile the time within every function, use the AdvancedProfiler built on top of Python’s cProfiler.
# ```python
# trainer = Trainer(profiler="advanced")
# ```
#
# Once the .fit() function has completed, you’ll see an output like this:
# ```
# Profiler Report
#
# Profile stats for: get_train_batch
#         4869394 function calls (4863767 primitive calls) in 18.893 seconds
# Ordered by: cumulative time
# List reduced from 76 to 10 due to restriction <10>
# ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 3752/1876    0.011    0.000   18.887    0.010 {built-in method builtins.next}
#     1876     0.008    0.000   18.877    0.010 dataloader.py:344(__next__)
#     1876     0.074    0.000   18.869    0.010 dataloader.py:383(_next_data)
#     1875     0.012    0.000   18.721    0.010 fetch.py:42(fetch)
#     1875     0.084    0.000   18.290    0.010 fetch.py:44(<listcomp>)
#     60000    1.759    0.000   18.206    0.000 mnist.py:80(__getitem__)
#     60000    0.267    0.000   13.022    0.000 transforms.py:68(__call__)
#     60000    0.182    0.000    7.020    0.000 transforms.py:93(__call__)
#     60000    1.651    0.000    6.839    0.000 functional.py:42(to_tensor)
#     60000    0.260    0.000    5.734    0.000 transforms.py:167(__call__)
# ```
#
# 如果分析器报告太长，您可以将报告传输到一个文件:
# ```pytorch
# from lightning.pytorch.profilers import AdvancedProfiler
#
# profiler = AdvancedProfiler(dirpath=".", filename="perf_logs")
# trainer = Trainer(profiler=profiler)
# ```

# %% [markdown]
# # Measure accelerator usage
# 检测瓶颈的另一个有用技术是确保您正在使用加速器的全部容量(GPU/TPU/IPU/HPU)。这可以通过 DeviceStatsMonitor 来衡量:
# ```python
# from lightning.pytorch.callbacks import DeviceStatsMonitor
#
# trainer = Trainer(callbacks=[DeviceStatsMonitor()])
# ```
#
# CPU 指标将在 CPU 加速器上默认跟踪。要为其他加速器启用它，请设置 DeviceStatsMonitor (cpu _ stats = True)。要禁用日志 CPU 指标，可以指定 DeviceStatsMonitor (CPU _ stats = False)。

# %% [markdown]
# # Experiment

# %%
from json import encoder

import torch.utils.data as data
import torch
import torch.nn as nn
from torchvision import datasets
import torchvision.transforms as transforms
import os
import torch.nn.functional as F
from torchvision import transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
import lightning as L

# %%
# Load data sets
transform = transforms.ToTensor()
train_set = datasets.MNIST(root="MNIST", download=True, train=True, transform=transform)
test_set = datasets.MNIST(root="MNIST", download=True, train=False, transform=transform)
train_loader = DataLoader(train_set, num_workers=0, batch_size=64, shuffle=True)
test_loader = DataLoader(test_set, num_workers=0, batch_size=64, shuffle=True)

# %%
# PyTorch
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.l1 = nn.Sequential(nn.Linear(28 * 28, 64), nn.ReLU(), nn.Linear(64, 3))

    def forward(self, x):
        return self.l1(x)


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.l1 = nn.Sequential(nn.Linear(3, 64), nn.ReLU(), nn.Linear(64, 28 * 28))

    def forward(self, x):
        return self.l1(x)

# %%
# PyTorch-Lightning
class LitAutoEncoder(L.LightningModule):
    def __init__(self, encoder, decoder):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        # Example input array for logging and model tracing
        self.example_input_array = torch.rand(16, 1, 28, 28)
    
    def forward(self, x):
         # Define the forward pass
        x = x.view(x.size(0), -1)  # Flatten the input
        z = self.encoder(x)
        x_hat = self.decoder(z)
        return x_hat
        

    def training_step(self, batch, batch_idx):
        # training_step defines the train loop.
        x, y = batch
        x_hat = self(x)  # Use the forward method
        loss = F.mse_loss(x_hat, x.view(x.size(0), -1))
        return loss
    
    def test_step(self, batch, batch_idx):
        # this is the test loop
        x, y = batch
        x_hat = self(x)  # Use the forward method
        test_loss = F.mse_loss(x_hat, x.view(x.size(0), -1))
        self.log("test_loss", test_loss)

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-3)
        return optimizer

# %%
model = LitAutoEncoder.load_from_checkpoint("ckpts/lightning_logs/version_0/checkpoints/epoch=2-step=2250.ckpt",encoder=Encoder(), decoder=Decoder())

# %%
trainer = L.Trainer(num_sanity_val_steps=2,accelerator='gpu', max_epochs=3,profiler="simple")
trainer.fit(model, train_loader, test_loader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params | In sizes  | Out sizes
# ------------------------------------------------------------
# 0 | encoder | Encoder | 50.4 K | [16, 784] | [16, 3]
# 1 | decoder | Decoder | 51.2 K | [16, 3]   | [16, 784]
# ------------------------------------------------------------
# 101 K     Trainable params
# 0         Non-trainable params
# 101 K     Total params
# 0.407     Total estimated model params size (MB)
# Training: |                                                                                                   …
# `Trainer.fit` stopped: `max_epochs=3` reached.
# FIT Profiler Report
#
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                        	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                         	|  -              	|  101375         	|  26.422         	|  100 %          	|
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                            	|  8.7863         	|  3              	|  26.359         	|  99.762         	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                                    	|  0.0055117      	|  2814           	|  15.51          	|  58.701         	|
# |  run_training_batch                                                                                                                                            	|  0.0025675      	|  2814           	|  7.225          	|  27.345         	|
# |  [LightningModule]LitAutoEncoder.optimizer_step                                                                                                                	|  0.0025231      	|  2814           	|  7.1            	|  26.872         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                       	|  0.00097264     	|  2814           	|  2.737          	|  10.359         	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                                                                                                                  	|  0.00072957     	|  2814           	|  2.053          	|  7.77           	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                  	|  0.00072886     	|  2814           	|  2.051          	|  7.7625         	|
# |  [LightningModule]LitAutoEncoder.optimizer_zero_grad                                                                                                           	|  0.00018799     	|  2814           	|  0.529          	|  2.0021         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                	|  0.00015991     	|  2814           	|  0.45           	|  1.7031         	|
# |  [LightningModule]LitAutoEncoder.transfer_batch_to_device                                                                                                      	|  0.00014316     	|  2815           	|  0.403          	|  1.5252         	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_end      	|  1.7058e-05     	|  2814           	|  0.048          	|  0.18167        	|
# |  [LightningModule]LitAutoEncoder.configure_gradient_clipping                                                                                                   	|  1.1372e-05     	|  2814           	|  0.032          	|  0.12111        	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                	|  0.0053333      	|  3              	|  0.016          	|  0.060556       	|
# |  [Callback]TQDMProgressBar.on_train_batch_start                                                                                                                	|  5.6859e-06     	|  2814           	|  0.016          	|  0.060556       	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                    	|  5.6859e-06     	|  2814           	|  0.016          	|  0.060556       	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                  	|  5.6859e-06     	|  2814           	|  0.016          	|  0.060556       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_end      	|  0.0053333      	|  3              	|  0.016          	|  0.060556       	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                   	|  5.3305e-06     	|  2814           	|  0.015          	|  0.056771       	|
# |  [LightningModule]LitAutoEncoder.configure_callbacks                                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.prepare_data                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                               	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.setup                                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.setup                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.configure_optimizers                                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_before_batch_transfer                                                                                                      	|  0.0            	|  2815           	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_after_batch_transfer                                                                                                       	|  0.0            	|  2815           	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start            	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_fit_start                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                      	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_start          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_start                                                                                                                	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                   	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_start    	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_epoch_start                                                                                                          	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_batch_start                                                                                                                   	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_start    	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_batch_start                                                                                                          	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                           	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                 	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_zero_grad     	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_before_zero_grad                                                                                                           	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                     	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_backward      	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_before_backward                                                                                                            	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                      	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_after_backward       	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_after_backward                                                                                                             	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                            	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                               	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_optimizer_step	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_before_optimizer_step                                                                                                      	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_batch_end                                                                                                                     	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_batch_end                                                                                                            	|  0.0            	|  2814           	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                  	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                     	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_epoch_end                                                                                                            	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                  	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                     	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint      	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_save_checkpoint                                                                                                            	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end            	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_end                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                             	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end              	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_fit_end                                                                                                                    	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                            	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.teardown                                                                                                                               	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown                	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.teardown                                                                                                                      	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
trainer = L.Trainer(num_sanity_val_steps=2,accelerator='gpu', max_epochs=3,profiler="advanced")
trainer.fit(model, train_loader, test_loader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params | In sizes  | Out sizes
# ------------------------------------------------------------
# 0 | encoder | Encoder | 50.4 K | [16, 784] | [16, 3]
# 1 | decoder | Decoder | 51.2 K | [16, 3]   | [16, 784]
# ------------------------------------------------------------
# 101 K     Trainable params
# 0         Non-trainable params
# 101 K     Total params
# 0.407     Total estimated model params size (MB)
# Training: |                                                                                                   …
# `Trainer.fit` stopped: `max_epochs=3` reached.
# FIT Profiler Report
# Profile stats for: [LightningModule]LitAutoEncoder.configure_callbacks
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 module.py:923(configure_callbacks)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.prepare_data
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 hooks.py:362(prepare_data)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#
#
#
# Profile stats for: [Callback]TQDMProgressBar.setup
#          13 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 progress_bar.py:171(setup)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1252(is_global_zero)
#         2    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 single_device.py:81(is_global_zero)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [Callback]ModelSummary.setup
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         1    0.000    0.000    0.000    0.000 callback.py:58(setup)
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#
#
#
# Profile stats for: [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup
#          125 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 model_checkpoint.py:268(setup)
#         1    0.000    0.000    0.000    0.000 model_checkpoint.py:651(__warn_if_dir_not_empty)
#         1    0.000    0.000    0.000    0.000 cloud_io.py:105(_is_dir)
#         1    0.000    0.000    0.000    0.000 local.py:133(isdir)
#         1    0.000    0.000    0.000    0.000 genericpath.py:39(isdir)
#         1    0.000    0.000    0.000    0.000 {built-in method nt.stat}
#         1    0.000    0.000    0.000    0.000 cloud_io.py:60(get_filesystem)
#         1    0.000    0.000    0.000    0.000 core.py:362(url_to_fs)
#         1    0.000    0.000    0.000    0.000 model_checkpoint.py:609(__resolve_ckpt_dir)
#         1    0.000    0.000    0.000    0.000 core.py:331(_un_chain)
#         2    0.000    0.000    0.000    0.000 local.py:230(_strip_protocol)
#         1    0.000    0.000    0.000    0.000 registry.py:289(filesystem)
#         1    0.000    0.000    0.000    0.000 spec.py:65(__call__)
#         1    0.000    0.000    0.000    0.000 ntpath.py:107(join)
#         2    0.000    0.000    0.000    0.000 local.py:280(make_path_posix)
#         1    0.000    0.000    0.000    0.000 utils.py:306(tokenize)
#         4    0.000    0.000    0.000    0.000 ntpath.py:154(splitdrive)
#         1    0.000    0.000    0.000    0.000 cloud_io.py:83(_is_object_storage)
#         1    0.000    0.000    0.000    0.000 enums.py:81(__eq__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         4    0.000    0.000    0.000    0.000 utils.py:327(stringify_path)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 __init__.py:225(compile)
#         9    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 registry.py:222(get_filesystem_class)
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 core.py:541(split_protocol)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_md5}
#         6    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 __init__.py:272(_compile)
#         1    0.000    0.000    0.000    0.000 config.py:99(apply_config)
#        15    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 enum.py:193(__get__)
#         2    0.000    0.000    0.000    0.000 csv_logs.py:136(save_dir)
#         1    0.000    0.000    0.000    0.000 trainer.py:1252(is_global_zero)
#         1    0.000    0.000    0.000    0.000 csv_logs.py:78(name)
#         5    0.000    0.000    0.000    0.000 trainer.py:1601(loggers)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 csv_logs.py:89(version)
#         3    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         5    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         3    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 enum.py:1257(value)
#         2    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 core.py:395(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 spec.py:67(<genexpr>)
#         1    0.000    0.000    0.000    0.000 spec.py:214(_get_kwargs_from_urls)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 single_device.py:81(is_global_zero)
#         1    0.000    0.000    0.000    0.000 single_device.py:90(broadcast)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.setup
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 hooks.py:418(setup)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.configure_optimizers
#          374 function calls (340 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 3258969632.py:32(configure_optimizers)
#         1    0.000    0.000    0.000    0.000 adam.py:15(__init__)
#         1    0.000    0.000    0.000    0.000 optimizer.py:250(__init__)
#         1    0.000    0.000    0.000    0.000 _compile.py:20(inner)
#         1    0.000    0.000    0.000    0.000 decorators.py:36(disable)
#         1    0.000    0.000    0.000    0.000 eval_frame.py:351(__call__)
#         1    0.000    0.000    0.000    0.000 inspect.py:932(getsourcefile)
#         9    0.000    0.000    0.000    0.000 module.py:2207(parameters)
#         1    0.000    0.000    0.000    0.000 genericpath.py:16(exists)
#         9    0.000    0.000    0.000    0.000 module.py:2232(named_parameters)
#         1    0.000    0.000    0.000    0.000 {built-in method nt.stat}
#         9    0.000    0.000    0.000    0.000 module.py:2193(_named_members)
#         1    0.000    0.000    0.000    0.000 trace_rules.py:3377(check)
#         1    0.000    0.000    0.000    0.000 trace_rules.py:3342(check_verbose)
#         1    0.000    0.000    0.000    0.000 eval_frame.py:428(_fn)
#         1    0.000    0.000    0.000    0.000 optimizer.py:863(add_param_group)
#     46/12    0.000    0.000    0.000    0.000 module.py:2369(named_modules)
#         1    0.000    0.000    0.000    0.000 trace_rules.py:3432(lookup_inner)
#         2    0.000    0.000    0.000    0.000 package_importer.py:694(_patched_getfile)
#        40    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 inspect.py:892(getfile)
#         1    0.000    0.000    0.000    0.000 trace_rules.py:3275(check_file)
#         1    0.000    0.000    0.000    0.000 eval_frame.py:550(__init__)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        32    0.000    0.000    0.000    0.000 _tensor.py:1059(__hash__)
#         1    0.000    0.000    0.000    0.000 eval_frame.py:290(__init__)
#         1    0.000    0.000    0.000    0.000 functools.py:35(update_wrapper)
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._log_api_usage_once}
#         1    0.000    0.000    0.000    0.000 eval_frame.py:448(<listcomp>)
#         3    0.000    0.000    0.000    0.000 base.py:127(__instancecheck__)
#        11    0.000    0.000    0.000    0.000 module.py:2260(<lambda>)
#         1    0.000    0.000    0.000    0.000 utils.py:862(getfile)
#         1    0.000    0.000    0.000    0.000 optimizer.py:417(_patch_step_function)
#         1    0.000    0.000    0.000    0.000 eval_frame.py:141(change)
#        19    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 trace_rules.py:2840(is_aten_op_or_tensor_method)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         5    0.000    0.000    0.000    0.000 trace_rules.py:3279(<genexpr>)
#         3    0.000    0.000    0.000    0.000 eval_frame.py:265(innermost_fn)
#         3    0.000    0.000    0.000    0.000 inspect.py:939(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#        33    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         4    0.000    0.000    0.000    0.000 inspect.py:292(isclass)
#         1    0.000    0.000    0.000    0.000 eval_frame.py:119(backend_cache_manager)
#         1    0.000    0.000    0.000    0.000 utils.py:435(hashable)
#        11    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 functools.py:65(wraps)
#        22    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         2    0.000    0.000    0.000    0.000 inspect.py:283(ismodule)
#         2    0.000    0.000    0.000    0.000 inspect.py:300(ismethod)
#         4    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 inspect.py:466(isframe)
#        10    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 inspect.py:942(<genexpr>)
#         2    0.000    0.000    0.000    0.000 inspect.py:456(istraceback)
#         2    0.000    0.000    0.000    0.000 inspect.py:480(iscode)
#         4    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method torch._C._dynamo.eval_frame.set_eval_frame}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 inspect.py:378(isfunction)
#         6    0.000    0.000    0.000    0.000 {function VariableTrackerMeta.__instancecheck__ at 0x000002B48C509440}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 eval_frame.py:149(revert)
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 eval_frame.py:261(always_false)
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 typing.py:2287(cast)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 eval_frame.py:257(nothing)
#
#
#
# Profile stats for: [Callback]TQDMProgressBar.on_fit_start
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 callback.py:64(on_fit_start)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [Callback]ModelSummary.on_fit_start
#          75 function calls (74 primitive calls) in 0.002 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 model_summary.py:59(on_fit_start)
#         1    0.000    0.000    0.002    0.002 model_summary.py:73(_summary)
#         1    0.000    0.000    0.002    0.002 model_summary.py:462(summarize)
#         1    0.000    0.000    0.002    0.002 model_summary.py:203(__init__)
#         1    0.000    0.000    0.002    0.002 model_summary.py:268(summarize)
#         1    0.000    0.000    0.002    0.002 model_summary.py:282(_forward_example_input)
#         1    0.000    0.000    0.002    0.002 module.py:340(_on_before_batch_transfer)
#         1    0.000    0.000    0.002    0.002 module.py:325(_call_batch_hook)
#         1    0.000    0.000    0.002    0.002 call.py:135(_call_lightning_module_hook)
#         1    0.000    0.000    0.002    0.002 contextlib.py:132(__enter__)
#         1    0.000    0.000    0.002    0.002 {built-in method builtins.next}
#         1    0.000    0.000    0.002    0.002 profiler.py:55(profile)
#         1    0.000    0.000    0.002    0.002 advanced.py:65(start)
#         1    0.002    0.002    0.002    0.002 {method 'enable' of '_lsprof.Profiler' objects}
#         3    0.000    0.000    0.000    0.000 model_summary.py:269(<genexpr>)
#         2    0.000    0.000    0.000    0.000 model_summary.py:72(__init__)
#         2    0.000    0.000    0.000    0.000 model_summary.py:82(_register_hook)
#         2    0.000    0.000    0.000    0.000 module.py:1442(register_forward_hook)
#         2    0.000    0.000    0.000    0.000 hooks.py:23(__init__)
#     12/11    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 module.py:1711(__setattr__)
#         1    0.000    0.000    0.000    0.000 model_summary.py:217(named_modules)
#         3    0.000    0.000    0.000    0.000 module.py:2322(named_children)
#         1    0.000    0.000    0.000    0.000 parameter.py:8(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:299(helper)
#         1    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1467(debug)
#         6    0.000    0.000    0.000    0.000 hooks.py:32(<genexpr>)
#         2    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         2    0.000    0.000    0.000    0.000 module.py:238(example_input_array)
#         1    0.000    0.000    0.000    0.000 __init__.py:1734(isEnabledFor)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 data_connector.py:366(get_instance)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         2    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         3    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {function _ParameterMeta.__instancecheck__ at 0x000002B486091800}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.on_before_batch_transfer
#          19705 function calls in 0.006 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2815    0.002    0.000    0.006    0.000 contextlib.py:141(__exit__)
#      2815    0.001    0.000    0.004    0.000 {built-in method builtins.next}
#      2815    0.001    0.000    0.004    0.000 profiler.py:55(profile)
#      2815    0.002    0.000    0.002    0.000 advanced.py:71(stop)
#      2815    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#      2815    0.000    0.000    0.000    0.000 hooks.py:615(on_before_batch_transfer)
#      2815    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.transfer_batch_to_device
#          90065 function calls in 0.362 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2815    0.003    0.000    0.353    0.000 hooks.py:562(transfer_batch_to_device)
#      2815    0.011    0.000    0.349    0.000 apply_func.py:71(move_data_to_device)
#      2815    0.009    0.000    0.337    0.000 apply_func.py:23(apply_to_collection)
#      2814    0.008    0.000    0.314    0.000 apply_func.py:66(<listcomp>)
#      5629    0.034    0.000    0.306    0.000 apply_func.py:91(batch_to)
#      5629    0.271    0.000    0.271    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#     22516    0.005    0.000    0.012    0.000 {built-in method builtins.isinstance}
#      2815    0.002    0.000    0.009    0.000 contextlib.py:141(__exit__)
#      2814    0.002    0.000    0.008    0.000 {built-in method builtins.all}
#      2815    0.002    0.000    0.007    0.000 {built-in method builtins.next}
#      8443    0.002    0.000    0.007    0.000 abc.py:117(__instancecheck__)
#      8442    0.002    0.000    0.006    0.000 apply_func.py:65(<genexpr>)
#      2815    0.002    0.000    0.006    0.000 profiler.py:55(profile)
#      8443    0.005    0.000    0.005    0.000 {built-in method _abc._abc_instancecheck}
#      2815    0.003    0.000    0.004    0.000 advanced.py:71(stop)
#      2815    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#      2815    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.on_after_batch_transfer
#          19705 function calls in 0.006 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2815    0.001    0.000    0.006    0.000 contextlib.py:141(__exit__)
#      2815    0.001    0.000    0.004    0.000 {built-in method builtins.next}
#      2815    0.001    0.000    0.004    0.000 profiler.py:55(profile)
#      2815    0.002    0.000    0.003    0.000 advanced.py:71(stop)
#      2815    0.000    0.000    0.000    0.000 hooks.py:643(on_after_batch_transfer)
#      2815    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#      2815    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 callback.py:64(on_fit_start)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.on_fit_start
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 hooks.py:31(on_fit_start)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#
#
#
# Profile stats for: [Callback]TQDMProgressBar.on_train_start
#          16232 function calls (14632 primitive calls) in 0.010 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.010    0.010 tqdm_progress.py:259(on_train_start)
#         1    0.000    0.000    0.010    0.010 tqdm_progress.py:197(init_train_tqdm)
#         1    0.000    0.000    0.010    0.010 tqdm_progress.py:40(__init__)
#         1    0.000    0.000    0.010    0.010 notebook.py:202(__init__)
#         1    0.000    0.000    0.006    0.006 notebook.py:94(status_printer)
#      11/4    0.000    0.000    0.005    0.001 widget.py:500(__init__)
#      11/4    0.000    0.000    0.005    0.001 widget.py:522(open)
#  1528/902    0.001    0.000    0.005    0.000 traitlets.py:676(__get__)
#  1226/815    0.001    0.000    0.004    0.000 traitlets.py:629(get)
#     21/14    0.000    0.000    0.004    0.000 widget.py:589(get_state)
#         3    0.000    0.000    0.004    0.001 widget_description.py:30(__init__)
#   933/482    0.000    0.000    0.004    0.000 {built-in method builtins.getattr}
#     66/24    0.000    0.000    0.004    0.000 traitlets.py:1885(trait_defaults)
#     55/20    0.000    0.000    0.003    0.000 traitlets.py:591(default)
#         7    0.000    0.000    0.003    0.000 trait_types.py:408(make_dynamic_default)
#        21    0.000    0.000    0.003    0.000 comm.py:24(publish_msg)
#        22    0.000    0.000    0.002    0.000 session.py:754(send)
#         1    0.000    0.000    0.002    0.002 display_functions.py:105(display)
#         2    0.000    0.000    0.002    0.001 widget_string.py:64(__init__)
#         4    0.000    0.000    0.002    0.001 widget_layout.py:80(__init__)
#        25    0.000    0.000    0.002    0.000 traitlets.py:708(__set__)
#        28    0.000    0.000    0.002    0.000 traitlets.py:689(set)
#        11    0.000    0.000    0.002    0.000 comm.py:27(create_comm)
#        11    0.000    0.000    0.002    0.000 ipkernel.py:48(_create_comm)
#        11    0.000    0.000    0.002    0.000 base_comm.py:36(__init__)
#        23    0.000    0.000    0.002    0.000 traitlets.py:1512(_notify_trait)
#        24    0.000    0.000    0.002    0.000 widget.py:691(notify_change)
#         1    0.000    0.000    0.002    0.002 widget_float.py:23(__init__)
#        11    0.000    0.000    0.002    0.000 base_comm.py:92(open)
#        22    0.000    0.000    0.001    0.000 session.py:690(serialize)
#         1    0.000    0.000    0.001    0.001 formatters.py:93(format)
#        10    0.000    0.000    0.001    0.000 widget.py:570(send_state)
#        11    0.000    0.000    0.001    0.000 decorator.py:229(fun)
#         1    0.000    0.000    0.001    0.001 display_functions.py:45(publish_display_data)
#         1    0.000    0.000    0.001    0.001 zmqshell.py:81(publish)
#        10    0.000    0.000    0.001    0.000 widget.py:822(_send)
#        10    0.000    0.000    0.001    0.000 base_comm.py:143(send)
#         1    0.000    0.000    0.001    0.001 widget_box.py:62(__init__)
#        11    0.000    0.000    0.001    0.000 formatters.py:222(catch_format_error)
#         1    0.000    0.000    0.001    0.001 zmqshell.py:64(_flush_streams)
#         2    0.000    0.000    0.001    0.000 iostream.py:592(flush)
#        88    0.000    0.000    0.001    0.000 session.py:92(json_packer)
#         2    0.000    0.000    0.001    0.000 threading.py:611(wait)
#         2    0.000    0.000    0.001    0.000 threading.py:295(wait)
#        88    0.000    0.000    0.001    0.000 __init__.py:183(dumps)
#        36    0.001    0.000    0.001    0.000 {method 'acquire' of '_thread.lock' objects}
#        15    0.000    0.000    0.001    0.000 traitlets.py:1238(__call__)
#        11    0.000    0.000    0.001    0.000 widget.py:488(_default_keys)
#        32    0.000    0.000    0.001    0.000 traitlets.py:1911(traits)
#         1    0.000    0.000    0.001    0.001 notebook.py:139(display)
#        88    0.000    0.000    0.001    0.000 encoder.py:183(encode)
#        26    0.000    0.000    0.001    0.000 iostream.py:259(schedule)
#        22    0.000    0.000    0.001    0.000 iostream.py:343(send_multipart)
#        12    0.000    0.000    0.001    0.000 formatters.py:376(lookup)
#        88    0.000    0.000    0.001    0.000 encoder.py:205(iterencode)
#        22    0.000    0.000    0.001    0.000 iostream.py:271(send_multipart)
#       299    0.000    0.000    0.000    0.000 traitlets.py:1942(trait_metadata)
#        12    0.000    0.000    0.000    0.000 formatters.py:399(lookup_by_type)
#         9    0.000    0.000    0.000    0.000 formatters.py:333(__call__)
#        26    0.000    0.000    0.000    0.000 socket.py:626(send)
#         1    0.000    0.000    0.000    0.000 formatters.py:956(__call__)
#         3    0.000    0.000    0.000    0.000 utils.py:297(_screen_shape_windows)
#         1    0.000    0.000    0.000    0.000 widget.py:802(_repr_mimebundle_)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#         1    0.000    0.000    0.000    0.000 notebook.py:80(__repr__)
#         2    0.000    0.000    0.000    0.000 std.py:1446(format_dict)
#        22    0.000    0.000    0.000    0.000 session.py:649(msg)
#    100/94    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#        22    0.000    0.000    0.000    0.000 session.py:675(sign)
#        11    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#        90    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#       120    0.000    0.000    0.000    0.000 formatters.py:555(_in_deferred_types)
#        21    0.000    0.000    0.000    0.000 widget.py:132(_remove_buffers)
#        24    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#        22    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#     26/21    0.000    0.000    0.000    0.000 widget.py:87(_separate_buffers)
#        11    0.000    0.000    0.000    0.000 traitlets.py:1280(__new__)
#         1    0.000    0.000    0.000    0.000 asyncio.py:23(__init__)
#         2    0.000    0.000    0.000    0.000 std.py:464(format_meter)
#       501    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        11    0.000    0.000    0.000    0.000 traitlets.py:1337(__init__)
#         1    0.000    0.000    0.000    0.000 notebook.py:71(_json_)
#      2742    0.000    0.000    0.000    0.000 typing.py:2287(cast)
#         1    0.000    0.000    0.000    0.000 std.py:952(__init__)
#        11    0.000    0.000    0.000    0.000 traitlets.py:1323(setup_instance)
#      1352    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        11    0.000    0.000    0.000    0.000 inspect.py:3190(bind)
#        11    0.000    0.000    0.000    0.000 inspect.py:3059(_bind)
#        11    0.000    0.000    0.000    0.000 traitlets.py:1295(setup_instance)
#        10    0.000    0.000    0.000    0.000 widget.py:739(_should_send_property)
#        22    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#         2    0.000    0.000    0.000    0.000 utils.py:378(disp_len)
#        17    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#        11    0.000    0.000    0.000    0.000 uuid.py:721(uuid4)
#        24    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         2    0.000    0.000    0.000    0.000 utils.py:374(_text_width)
#        21    0.000    0.000    0.000    0.000 kernelbase.py:655(get_parent)
#       736    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        22    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#        11    0.000    0.000    0.000    0.000 base_comm.py:224(register_comm)
#        22    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#         1    0.000    0.000    0.000    0.000 formatters.py:910(__call__)
#        22    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#        28    0.000    0.000    0.000    0.000 threading.py:1192(is_alive)
#        11    0.000    0.000    0.000    0.000 widget.py:537(_comm_changed)
#        22    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#       345    0.000    0.000    0.000    0.000 traitlets.py:225(__call__)
#        66    0.000    0.000    0.000    0.000 traitlets.py:1873(_get_trait_default_generator)
#       211    0.000    0.000    0.000    0.000 utils.py:375(<genexpr>)
#         1    0.000    0.000    0.000    0.000 utils.py:386(disp_trim)
#        11    0.000    0.000    0.000    0.000 uuid.py:139(__init__)
#        22    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#        11    0.000    0.000    0.000    0.000 traitlets.py:1256(instance_init)
#        88    0.000    0.000    0.000    0.000 hmac.py:117(update)
#       122    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 inspect.py:2822(args)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 std.py:663(__new__)
#        11    0.000    0.000    0.000    0.000 traitlets.py:1641(observe)
#        32    0.000    0.000    0.000    0.000 widget.py:547(model_id)
#       345    0.000    0.000    0.000    0.000 traitlets.py:222(__init__)
#        22    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#        22    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#        22    0.000    0.000    0.000    0.000 session.py:854(<listcomp>)
#        88    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#        22    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#        11    0.000    0.000    0.000    0.000 inspect.py:2875(apply_defaults)
#      11/8    0.000    0.000    0.000    0.000 widget.py:48(_widget_to_json)
#        28    0.000    0.000    0.000    0.000 threading.py:1125(_wait_for_tstate_lock)
#        35    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 threading.py:562(__init__)
#        11    0.000    0.000    0.000    0.000 dir2.py:54(get_real_method)
#       380    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        11    0.000    0.000    0.000    0.000 inspect.py:2845(kwargs)
#        17    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#        15    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       353    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        30    0.000    0.000    0.000    0.000 traitlets.py:2322(instance_init)
#        88    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#        66    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 widget_float.py:51(_validate_max)
#        22    0.000    0.000    0.000    0.000 {built-in method now}
#         3    0.000    0.000    0.000    0.000 traitlets.py:1759(set_trait)
#        11    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#       356    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         3    0.000    0.000    0.000    0.000 __init__.py:48(create_string_buffer)
#        67    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        23    0.000    0.000    0.000    0.000 threading.py:1453(current_thread)
#       281    0.000    0.000    0.000    0.000 widget.py:792(_trait_to_json)
#       209    0.000    0.000    0.000    0.000 {built-in method unicodedata.east_asian_width}
#        11    0.000    0.000    0.000    0.000 comm.py:7(requires_ipykernel_shim)
#         2    0.000    0.000    0.000    0.000 std.py:110(__enter__)
#         2    0.000    0.000    0.000    0.000 notebook.py:192(colour)
#         4    0.000    0.000    0.000    0.000 traitlets.py:3271(validate)
#        11    0.000    0.000    0.000    0.000 traitlets.py:194(parse_notifier_name)
#        43    0.000    0.000    0.000    0.000 jsonutil.py:77(json_clean)
#        72    0.000    0.000    0.000    0.000 traitlets.py:1824(has_trait)
#         2    0.000    0.000    0.000    0.000 utils.py:266(_supports_unicode)
#         2    0.000    0.000    0.000    0.000 threading.py:243(__init__)
#        22    0.000    0.000    0.000    0.000 configurable.py:597(initialized)
#         7    0.000    0.000    0.000    0.000 traitlets.py:2807(validate)
#       124    0.000    0.000    0.000    0.000 inspect.py:2734(kind)
#         2    0.000    0.000    0.000    0.000 std.py:400(format_interval)
#        11    0.000    0.000    0.000    0.000 widget.py:490(<listcomp>)
#        30    0.000    0.000    0.000    0.000 traitlets.py:2327(_resolve_classes)
#         2    0.000    0.000    0.000    0.000 std.py:102(acquire)
#        26    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         7    0.000    0.000    0.000    0.000 trait_types.py:402(validate)
#         5    0.000    0.000    0.000    0.000 traitlets.py:3997(validate)
#         1    0.000    0.000    0.000    0.000 utils.py:213(__init__)
#        11    0.000    0.000    0.000    0.000 {built-in method nt.urandom}
#        11    0.000    0.000    0.000    0.000 traitlets.py:1570(_add_notifiers)
#        34    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#       131    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#        34    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFD9670C4C0}
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        22    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#        33    0.000    0.000    0.000    0.000 traitlets.py:1245(__get__)
#        13    0.000    0.000    0.000    0.000 configurable.py:553(instance)
#         3    0.000    0.000    0.000    0.000 traitlets.py:1264(instance_init)
#         2    0.000    0.000    0.000    0.000 notebook.py:197(colour)
#         1    0.000    0.000    0.000    0.000 __init__.py:198(split)
#        11    0.000    0.000    0.000    0.000 uuid.py:334(hex)
#         8    0.000    0.000    0.000    0.000 utils.py:222(__eq__)
#         1    0.000    0.000    0.000    0.000 widget.py:52(<listcomp>)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         4    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         3    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         2    0.000    0.000    0.000    0.000 std.py:113(__exit__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:85(add)
#         9    0.000    0.000    0.000    0.000 traitlets.py:2331(make_dynamic_default)
#        88    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 std.py:106(release)
#        66    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        44    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 widget_float.py:33(_validate_value)
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         3    0.000    0.000    0.000    0.000 traitlets.py:1711(_register_validator)
#        44    0.000    0.000    0.000    0.000 inspect.py:3015(parameters)
#        12    0.000    0.000    0.000    0.000 pretty.py:322(_get_mro)
#        12    0.000    0.000    0.000    0.000 formatters.py:276(_get_type)
#        11    0.000    0.000    0.000    0.000 inspect.py:292(isclass)
#        33    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#        23    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 functools.py:393(__get__)
#        21    0.000    0.000    0.000    0.000 threading.py:1152(name)
#        47    0.000    0.000    0.000    0.000 inspect.py:2722(name)
#        22    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 utils.py:252(_is_utf)
#         7    0.000    0.000    0.000    0.000 traitlets.py:2936(validate)
#         1    0.000    0.000    0.000    0.000 utils.py:273(_is_ascii)
#        11    0.000    0.000    0.000    0.000 inspect.py:2814(__init__)
#         1    0.000    0.000    0.000    0.000 std.py:186(__format__)
#         1    0.000    0.000    0.000    0.000 zmqshell.py:74(_hooks)
#        29    0.000    0.000    0.000    0.000 threading.py:575(is_set)
#         2    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'split' of 're.Pattern' objects}
#         7    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#        23    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        28    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        22    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         2    0.000    0.000    0.000    0.000 {built-in method fromtimestamp}
#        11    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         1    0.000    0.000    0.000    0.000 std.py:153(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:12(escape)
#         1    0.000    0.000    0.000    0.000 tqdm_progress.py:173(is_disabled)
#         1    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#         2    0.000    0.000    0.000    0.000 threading.py:274(__exit__)
#         2    0.000    0.000    0.000    0.000 std.py:231(__call__)
#         2    0.000    0.000    0.000    0.000 threading.py:283(_acquire_restore)
#         5    0.000    0.000    0.000    0.000 traitlets.py:4003(validate_elements)
#        11    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 formatters.py:947(_check_return)
#        11    0.000    0.000    0.000    0.000 widget.py:361(_call_widget_constructed)
#         2    0.000    0.000    0.000    0.000 threading.py:271(__enter__)
#         2    0.000    0.000    0.000    0.000 utils.py:187(disable_on_exception)
#         1    0.000    0.000    0.000    0.000 widget_float.py:41(_validate_min)
#         2    0.000    0.000    0.000    0.000 threading.py:280(_release_save)
#         1    0.000    0.000    0.000    0.000 utils.py:156(__init__)
#         1    0.000    0.000    0.000    0.000 tqdm_progress.py:169(is_enabled)
#         1    0.000    0.000    0.000    0.000 __init__.py:272(_compile)
#        26    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#        11    0.000    0.000    0.000    0.000 base_comm.py:165(on_msg)
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 std.py:1157(__hash__)
#         3    0.000    0.000    0.000    0.000 utils.py:152(wrapper_setattr)
#         1    0.000    0.000    0.000    0.000 std.py:760(get_lock)
#        11    0.000    0.000    0.000    0.000 ipkernel.py:58(_get_comm_manager)
#         1    0.000    0.000    0.000    0.000 utils.py:139(__getattr__)
#         1    0.000    0.000    0.000    0.000 _monitor.py:94(report)
#        15    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        22    0.000    0.000    0.000    0.000 traitlets.py:469(instance_init)
#        10    0.000    0.000    0.000    0.000 formatters.py:361(_check_return)
#         3    0.000    0.000    0.000    0.000 std.py:226(__init__)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         3    0.000    0.000    0.000    0.000 {built-in method time.time}
#         4    0.000    0.000    0.000    0.000 threading.py:1168(ident)
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#         2    0.000    0.000    0.000    0.000 utils.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 displaypub.py:45(_validate_data)
#         2    0.000    0.000    0.000    0.000 threading.py:286(_is_owned)
#         1    0.000    0.000    0.000    0.000 tqdm_progress.py:127(train_progress_bar)
#         1    0.000    0.000    0.000    0.000 std.py:167(colour)
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000    0.000    0.000 utils.py:282(_screen_shape_wrapper)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 tqdm_progress.py:161(refresh_rate)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#         1    0.000    0.000    0.000    0.000 std.py:163(colour)
#         1    0.000    0.000    0.000    0.000 utils.py:112(__format__)
#         1    0.000    0.000    0.000    0.000 progress_bar.py:64(train_description)
# ...
#         2    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method now}
#         1    0.000    0.000    0.000    0.000 utils.py:125(__eq__)
#         2    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         2    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 threading.py:1125(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 configurable.py:597(initialized)
#         1    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'split' of 're.Pattern' objects}
#         8    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#         2    0.000    0.000    0.000    0.000 threading.py:1453(current_thread)
#         2    0.000    0.000    0.000    0.000 std.py:1153(_comparable)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2807(validate)
#         2    0.000    0.000    0.000    0.000 utils.py:222(__eq__)
#         1    0.000    0.000    0.000    0.000 __init__.py:272(_compile)
#         1    0.000    0.000    0.000    0.000 std.py:1157(__hash__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2936(validate)
#         4    0.000    0.000    0.000    0.000 jsonutil.py:77(json_clean)
#         9    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         2    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#         1    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 std.py:231(__call__)
#         4    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#         8    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         6    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         2    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFD9670C4C0}
#         1    0.000    0.000    0.000    0.000 tqdm_progress.py:121(train_progress_bar)
#         2    0.000    0.000    0.000    0.000 threading.py:1152(name)
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 utils.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         2    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         1    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 widget.py:792(_trait_to_json)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         2    0.000    0.000    0.000    0.000 threading.py:575(is_set)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#
#
#
# Profile stats for: [Callback]ModelSummary.on_train_end
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 callback.py:208(on_train_end)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#
#
#
# Profile stats for: [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 callback.py:208(on_train_end)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.on_train_end
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 hooks.py:48(on_train_end)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [Strategy]SingleDeviceStrategy.on_train_end
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 strategy.py:563(on_train_end)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [Callback]TQDMProgressBar.on_fit_end
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 callback.py:67(on_fit_end)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [Callback]ModelSummary.on_fit_end
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 callback.py:67(on_fit_end)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 callback.py:67(on_fit_end)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.on_fit_end
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 hooks.py:38(on_fit_end)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#
#
#
# Profile stats for: [Callback]TQDMProgressBar.teardown
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         1    0.000    0.000    0.000    0.000 callback.py:61(teardown)
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [Callback]ModelSummary.teardown
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 callback.py:61(teardown)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#
# Profile stats for: [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 trainer.py:1189(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1136(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 callback.py:61(teardown)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.teardown
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:55(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:71(stop)
#         1    0.000    0.000    0.000    0.000 hooks.py:445(teardown)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}

# %%
from lightning.pytorch.callbacks import DeviceStatsMonitor
trainer = L.Trainer(num_sanity_val_steps=2,accelerator='gpu', max_epochs=3,callbacks=[DeviceStatsMonitor()])
trainer.fit(model, train_loader, test_loader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params | In sizes  | Out sizes
# ------------------------------------------------------------
# 0 | encoder | Encoder | 50.4 K | [16, 784] | [16, 3]
# 1 | decoder | Decoder | 51.2 K | [16, 3]   | [16, 784]
# ------------------------------------------------------------
# 101 K     Trainable params
# 0         Non-trainable params
# 101 K     Total params
# 0.407     Total estimated model params size (MB)
# Training: |                                                                                                   …
# `Trainer.fit` stopped: `max_epochs=3` reached.

# %% [markdown]
# # TRACK AND VISUALIZE EXPERIMENTS
#
# 想要可视化和监视他们的模型开发的用户
# 模型开发中，我们跟踪感兴趣的值，如确认损失，以可视化模型的学习过程。模型开发就像驾驶一辆没有窗户的汽车，图表和日志提供了知道在哪里驾驶汽车的窗口。有了“闪电”，你可以想象出任何你能想到的东西: 数字、文字、图像、音频。你的创造力和想象力是唯一的限制因素。

# %% [markdown]
# ## Track metrics
#
# Metric visualization is the most basic but powerful way of understanding how your model is doing throughout the model development process.
#
# To track a metric, simply use the self.log method available inside the LightningModule
#
# 度量可视化是理解您的模型在整个模型开发过程中如何运行的最基本但最强大的方法。要跟踪一个度量，只需使用 LightningModule 中提供的 self. log 方法
#
# ```python
# class LitModel(L.LightningModule):
#     def training_step(self, batch, batch_idx):
#         value = ...
#         self.log("some_value", value)
# ```
#
# To log multiple metrics at once, use self.log_dict:
#
# ```python
# values = {"loss": loss, "acc": acc, "metric_n": metric_n}  # add more items if needed
# self.log_dict(values)
# ```
#
# To view metrics in the commandline progress bar, set the prog_bar argument to True.
#
# ```python
# self.log(..., prog_bar=True)
# ```
#
# ```
# Epoch 3:  33%|███▉        | 307/938 [00:01<00:02, 289.04it/s, loss=0.198, v_num=51, acc=0.211, metric_n=0.937]`
# ```
